# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_export/books.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2000 non-null   int64
#  1   name              2000 non-null   object
#  2   price             2000 non-null   int64
#  3   original_price    2000 non-null   int64
#  4   rating_average    2000 non-null   float64
#  5   review_count      2000 non-null   int64
#  6   author            1710 non-null   object
#  7   category_path     2000 non-null   object
#  8   quantity_sold     1924 non-null   float64
#  9   inventory_status  2000 non-null   object
#  10  specifications    1985 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 172.0+ KB

# %%
df.head(10)
# Out:
#           id                                               name   price  \
# 0  277728224  Nói Chuyện Là Bản Năng, Giữ Miệng Là Tu Dưỡng,...  122800
# 1  277412034  Sách Song Ngữ Lời Thì Thầm Trong Tổ Ấm - Whisp...  180000
# 2  277409853  Bí Ẩn Thảm Án Ở Styles (Agatha Christie) (NXB ...   97600
# 3  277381902               Tiếng gọi chân trời - Nguyễn Ngọc Tư   68000
# 4  276960030                           Khi Mọi Điều Không Như Ý   80600
# 5  276948798  Lên Đỉnh Núi Mở Tiệm Bánh Mì - Triết lí Wazawa...   99000
# 6  276922095                                       Thế Hệ Lo Âu  139690
# 7  276823777                      Tại sao các quốc gia thất bại  258000
# 8  276346703  Combo 4 cuốn: ChatGPT + ChatGPT thực chiến + A...  608000
# 9  276159943  NEXUS - Lược Sử Của Những Mạng Lưới Thông Tin ...  227500
#
#    original_price  rating_average  review_count  \
# 0          127000             4.8           417
# 1          180000             5.0            22
# ...

# %%
df['specifications'].str.split('|', expand=True)
# Out:
#                                                    0  \
# 0                  Phiên bản sách: Phiên bản thường
# 1                   Công ty phát hành: NXB Lao Động
# 2                        Công ty phát hành: NXB Trẻ
# 3                        Công ty phát hành: NXB Trẻ
# 4                        Công ty phát hành: Nhã Nam
# ...                                              ...
# 1995                    Công ty phát hành: Megabook
# 1996                   Công ty phát hành: TGM Books
# 1997  Công ty phát hành: Cambridge University Press
# 1998       Công ty phát hành: Nhà Xuất Bản Kim Đồng
# 1999               Phiên bản sách: Phiên bản thường
#
#                                          1  \
# 0           Công ty phát hành: 1980 Books
# 1      Ngày xuất bản: 2025-02-19 00:41:13
# 2                       Loại bìa: Bìa mềm
# 3      Ngày xuất bản: 2025-03-04 00:00:00
# 4      Ngày xuất bản: 2025-03-01 00:00:00
# ...                                    ...
# ...

# %%
def parse_row(row):
    fields = row.split('|')
    field_dict ={}
    for i in row:
        if ':' in i:
            key, value = i.split(':', 1)
